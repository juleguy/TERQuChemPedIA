# %% [markdown]
# ## Entraînement des modèles DIST_REL_XY_05
#
# Modèles s'entraînant sur les données de DIST_REL_XY_02 avec les paramètres optimisés trouvés dans la recherche par quadrillage de DIST_REL_XY_01. (Depth = 9, LR = 0.001)
#
# On réduit également la taille de chaque couche : 225 -> ... -> 15.
# Puisque le réseau est composé de moins de neurones, on passe le dropout de 0.98 à 0.99
#
# ### JSONs

# %%
{
  "paths":{
        "train_set_loc":"../../data/train_set_riken_v2_reduced.h5",
        "test_set_loc":"../../data/test_set_riken_v2_reduced.h5",
        "train_prepared_input_loc":"../../data/DIST_REL_CC_05/train_prepared_input.h5",
        "test_prepared_input_loc":"../../data/DIST_REL_CC_05/test_prepared_input.h5",
        "train_labels_loc":"../../data/DIST_REL_CC_05/train_labels.h5",
        "test_labels_loc":"../../data/DIST_REL_CC_05/test_labels.h5",
        "model_loc":"../../models/DIST_REL_CC_05/dist_rel_cc_05.tflearn",
        "logs_dir":"../../models/DIST_REL_CC_05/logs/",
        "bonds_lengths_loc":"/home/jleguy/data/stats/CC/CC_bonds_lengths_total_set.h5",
        "plots_dir":"../../figures/"
  },
  "tasks":[
    {
      "prepare_model_data": {
        "selected_mols": {
          "mol_min_size": "2",
          "mol_max_size": "60",
          "max_anum": "9",
          "anum_1": "6",
          "anum_2": "6",
          "min_bond_size": "0",
          "max_bond_size": "1.6",
          "bond_max_neighbours" : "15"
        },
        "params": {
          "nb_mol_from_train": "800000",
          "nb_mol_from_test": "160000",
          "pos_class": "True",
          "one_hot_anums": "True",
          "amasses": "True",
          "distances": "True",
          "distances_cut_off": "2",
          "batch_size": "10000",
          "distances_fun":"identity"
        }
      }
    },
    {
      "model_train": {
        "model_name": "DIST_REL_CC_05",
        "model_type": "NN",
        "params": {
          "epochs": "600",
          "last_layer_width": "15",
          "batch_size": "5000",
          "learning_rate": "0.001",
          "epsilon": "0.001",
          "stddev_init": "0.001",
          "hidden_act": "elu",
          "outlayer_act": "linear",
          "depth": "9",
          "weight_decay": "0.001",
          "gpu_mem_prop": "0.3",
          "save_model": "True",
          "dropout": "0.99"
        }
      }
    }
  ]
}

# %%
{
  "paths":{
        "train_set_loc":"../../data/train_set_riken_v2_reduced.h5",
        "test_set_loc":"../../data/test_set_riken_v2_reduced.h5",
        "train_prepared_input_loc":"../../data/DIST_REL_CH_05/train_prepared_input.h5",
        "test_prepared_input_loc":"../../data/DIST_REL_CH_05/test_prepared_input.h5",
        "train_labels_loc":"../../data/DIST_REL_CH_05/train_labels.h5",
        "test_labels_loc":"../../data/DIST_REL_CH_05/test_labels.h5",
        "model_loc":"../../models/DIST_REL_CH_05/dist_rel_ch_05.tflearn",
        "logs_dir":"../../models/DIST_REL_CH_05/logs/",
        "bonds_lengths_loc":"/home/jleguy/data/stats/CH/CH_bonds_lengths_total_set.h5",
        "plots_dir":"../../figures/"
  },
  "tasks":[
    {
      "prepare_model_data": {
        "selected_mols": {
          "mol_min_size": "2",
          "mol_max_size": "60",
          "max_anum": "9",
          "anum_1": "6",
          "anum_2": "1",
          "min_bond_size": "0.83",
          "max_bond_size": "1.31",
          "bond_max_neighbours" : "15"
        },
        "params": {
          "nb_mol_from_train": "333000",
          "nb_mol_from_test": "106000",
          "pos_class": "True",
          "one_hot_anums": "True",
          "amasses": "True",
          "distances": "True",
          "distances_cut_off": "2",
          "batch_size": "10000",
          "distances_fun":"identity"
        }
      }
    },
    {
      "model_train": {
        "model_name": "DIST_REL_CH_05",
        "model_type": "NN",
        "params": {
          "epochs": "600",
          "last_layer_width": "15",
          "batch_size": "5000",
          "learning_rate": "0.001",
          "epsilon": "0.001",
          "stddev_init": "0.001",
          "hidden_act": "elu",
          "outlayer_act": "linear",
          "depth": "9",
          "weight_decay": "0.001",
          "gpu_mem_prop": "0.3",
          "save_model": "True",
          "dropout": "0.99"
        }
      }
    }
  ]
}

# %%
{
  "paths": {
    "train_set_loc": "../../data/train_set_riken_v2_reduced.h5",
    "test_set_loc": "../../data/test_set_riken_v2_reduced.h5",
    "train_prepared_input_loc": "../../data/DIST_REL_OH_05/train_prepared_input.h5",
    "test_prepared_input_loc": "../../data/DIST_REL_OH_05/test_prepared_input.h5",
    "train_labels_loc": "../../data/DIST_REL_OH_05/train_labels.h5",
    "test_labels_loc": "../../data/DIST_REL_OH_05/test_labels.h5",
    "model_loc": "../../models/DIST_REL_OH_05/dist_rel_oh_05.tflearn",
    "logs_dir": "../../models/DIST_REL_OH_05/logs/",
    "bonds_lengths_loc": "/home/jleguy/data/stats/OH/OH_bonds_lengths_total_set.h5",
    "plots_dir": "../../figures/"
  },
  "tasks": [
    {
      "prepare_model_data": {
        "selected_mols": {
          "mol_min_size": "2",
          "mol_max_size": "60",
          "max_anum": "9",
          "anum_1": "8",
          "anum_2": "1",
          "min_bond_size": "0.9",
          "max_bond_size": "1.25",
          "bond_max_neighbours": "15"
        },
        "params": {
          "nb_mol_from_train": "16000000",
          "nb_mol_from_test": "3200000",
          "pos_class": "True",
          "one_hot_anums": "True",
          "amasses": "True",
          "distances": "True",
          "distances_cut_off": "2",
          "batch_size": "10000",
          "distances_fun": "identity"
        }
      }
    },
    {
      "model_train": {
        "model_name": "DIST_REL_OH_05",
        "model_type": "NN",
        "params": {
          "epochs": "600",
          "last_layer_width": "15",
          "batch_size": "5000",
          "learning_rate": "0.001",
          "epsilon": "0.001",
          "stddev_init": "0.001",
          "hidden_act": "elu",
          "outlayer_act": "linear",
          "depth": "9",
          "weight_decay": "0.001",
          "gpu_mem_prop": "0.3",
          "save_model": "True",
          "dropout": "0.99"
        }
      }
    }
  ]
}

# %% [markdown]
# ## Analyse des résulats
#
# ### JSON

# %%
{
  "tasks":[
    {
      "plot_predictions":{
        "paths":{
          "test_prepared_input_loc":"../../data/DIST_REL_OH_05/test_prepared_input.h5",
          "test_labels_loc":"../../data/DIST_REL_OH_05/test_labels.h5",
          "plots_dir":"../../figures/DIST_REL_OH_05/",
          "logs_dir":"../../models/DIST_REL_OH_05/logs/",
          "bonds_lengths_loc":"/home/jleguy/data/stats/OH/OH_bonds_lengths_total_set.h5",
          "model_loc":"../../models/DIST_REL_OH_05/dist_rel_oh_05.tflearn"
        },
        "params":{
          "model_name":"DIST_REL_OH_05",
          "model_type":"NN",
          "anum_1":"8",
          "anum_2":"1",
          "plot_error_distrib":"True",
          "plot_targets_error_distrib":"True",
          "plot_targets_predictions":"True",
          "asymb_1":"O",
          "asymb_2":"H",
          "batch_size":"2000",
          "last_layer_width":"15",
          "hidden_act":"elu",
          "depth":"9",
          "outlayer_act":"linear",
          "display_plots":"True"

        }
      }
    },
    {
      "plot_predictions":{
        "paths":{
          "test_prepared_input_loc":"../../data/DIST_REL_CH_05/test_prepared_input.h5",
          "test_labels_loc":"../../data/DIST_REL_CH_05/test_labels.h5",
          "plots_dir":"../../figures/DIST_REL_CH_05/",
          "logs_dir":"../../models/DIST_REL_CH_05/logs/",
          "bonds_lengths_loc":"/home/jleguy/data/stats/CH/CH_bonds_lengths_total_set.h5",
          "model_loc":"../../models/DIST_REL_CH_05/dist_rel_ch_05.tflearn"
        },
        "params":{
          "model_name":"DIST_REL_CH_05",
          "model_type":"NN",
          "anum_1":"6",
          "anum_2":"1",
          "plot_error_distrib":"True",
          "plot_targets_error_distrib":"True",
          "plot_targets_predictions":"True",
          "asymb_1":"C",
          "asymb_2":"H",
          "batch_size":"2000",
          "last_layer_width":"15",
          "depth":"9",
          "hidden_act":"elu",
          "outlayer_act":"linear",
          "display_plots":"True"

        }
      }
    },
    {
      "plot_predictions_IGNORED":{
        "paths":{
          "test_prepared_input_loc":"../../data/DIST_REL_CC_05/test_prepared_input.h5",
          "test_labels_loc":"../../data/DIST_REL_CC_05/test_labels.h5",
          "plots_dir":"../../figures/DIST_REL_OH_05/",
          "logs_dir":"../../models/DIST_REL_CC_05/logs/",
          "bonds_lengths_loc":"/home/jleguy/data/stats/CC/CC_bonds_lengths_total_set.h5",
          "model_loc":"../../models/DIST_REL_CC_05/dist_rel_cc_05.tflearn"
        },
        "params":{
          "model_name":"DIST_REL_CC_05",
          "model_type":"NN",
          "anum_1":"6",
          "anum_2":"6",
          "plot_error_distrib":"True",
          "plot_targets_error_distrib":"True",
          "plot_targets_predictions":"True",
          "asymb_1":"C",
          "asymb_2":"C",
          "batch_size":"2000",
          "last_layer_width":"15",
          "depth":"9",
          "hidden_act":"elu",
          "outlayer_act":"linear",
          "display_plots":"True"
        }
      }
    }
  ]
}

# %% [markdown]
# ### Modèle DIST_REL_CC_05
#
# #### Statistiques erreurs (pm)
#
# ```
# Plotting DIST_REL_CC_05
# Dataset size : 1106823
# Mean error : 0.3239632
# Median error : 0.24752197
# Standard deviation : 0.33725548
# Min error : 0.0
# Max error : 26.608227
# Relative error : 0.21988484%
# ```
#
# #### Distribution des erreurs
#
# ![title](../figures/DIST_REL_CC_05/DIST_REL_CC_05_distrib_rmse_val.png)
#
# #### Erreurs en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CC_05/DIST_REL_CC_05_distrib_rmse_dist.png)
#
#
# #### Prédiction en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CC_05/DIST_REL_CC_05_preds_targets.png)
#
#
#
# ### Modèle DIST_REL_CH_05
#
# #### Statistiques erreurs (pm)
#
# ```
# Plotting DIST_REL_CH_05
# Dataset size : 1158250
# Mean error : 0.1739533
# Median error : 0.13410644
# Standard deviation : 0.16212614
# Min error : 0.0
# Max error : 8.120349
# Relative error : 0.15876736%
#
#
# ```
#
# #### Distribution des erreurs
#
# ![title](../figures/DIST_REL_CH_05/DIST_REL_CH_05_distrib_rmse_val.png)
#
#
# #### Erreurs en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CH_05/DIST_REL_CH_05_distrib_rmse_dist.png)
#
#
# #### Prédiction en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CH_05/DIST_REL_CH_05_preds_targets.png)
#
#
# ### Modèle DIST_REL_OH_05
#
# #### Statistiques erreurs (pm)
#
# ```
# Plotting DIST_REL_OH_05
# Dataset size : 143588
# Mean error : 0.183236
# Median error : 0.13167115
# Standard deviation : 0.18621174
# Min error : 0.0
# Max error : 6.768225
# Relative error : 0.18732%
# ```
#
# #### Distribution des erreurs
#
# ![title](../figures/DIST_REL_OH_05/DIST_REL_OH_05_distrib_rmse_val.png)
#
# #### Erreurs en fonction des distances cibles
#
# ![title](../figures/DIST_REL_OH_05/DIST_REL_OH_05_distrib_rmse_dist.png)
#
#
# #### Prédiction en fonction des distances cibles
#
# ![title](../figures/DIST_REL_OH_05/DIST_REL_OH_05_preds_targets.png)

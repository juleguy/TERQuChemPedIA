# %% [markdown]
# ## Analyse des performances des modèles DIST_REL_XY_04
#
# Inverse des distances
#
# ### JSON

# %%
{
  "tasks":[
    {
      "plot_predictions":{
        "paths":{
          "test_prepared_input_loc":"../../data/DIST_REL_OH_04/test_prepared_input.h5",
          "test_labels_loc":"../../data/DIST_REL_OH_04/test_labels.h5",
          "plots_dir":"../../figures/DIST_REL_OH_04/",
          "bonds_lengths_loc":"/home/jleguy/data/stats/OH/OH_bonds_lengths_total_set.h5",
          "model_loc":"../../models/DIST_REL_OH_04/dist_rel_oh_04.tflearn"
        },
        "params":{
          "model_name":"DIST_REL_OH_04",
          "model_type":"NN",
          "anum_1":"8",
          "anum_2":"1",
          "plot_error_distrib":"True",
          "plot_targets_error_distrib":"True",
          "plot_targets_predictions":"True",
          "batch_size":"2000",
          "last_layer_width":"870",
          "depth":"3",
          "hidden_act":"elu",
          "outlayer_act":"linear",
          "display_plots":"True"
        }
      }
    },
    {
      "plot_predictions":{
        "paths":{
          "test_prepared_input_loc":"../../data/DIST_REL_CH_04/test_prepared_input.h5",
          "test_labels_loc":"../../data/DIST_REL_CH_04/test_labels.h5",
          "plots_dir":"../../figures/DIST_REL_CH_04/",
          "bonds_lengths_loc":"/home/jleguy/data/stats/CH/CH_bonds_lengths_total_set.h5",
          "model_loc":"../../models/DIST_REL_CH_04/dist_rel_ch_04.tflearn"
        },
        "params":{
          "model_name":"DIST_REL_CH_04",
          "model_type":"NN",
          "anum_1":"6",
          "anum_2":"1",
          "plot_error_distrib":"True",
          "plot_targets_error_distrib":"True",
          "plot_targets_predictions":"True",
          "batch_size":"2000",
          "last_layer_width":"870",
          "depth":"3",
          "hidden_act":"elu",
          "outlayer_act":"linear",
          "display_plots":"True"

        }
      }
    },
    {
      "plot_predictions":{
        "paths":{
          "test_prepared_input_loc":"../../data/DIST_REL_CC_04/test_prepared_input.h5",
          "test_labels_loc":"../../data/DIST_REL_CC_04/test_labels.h5",
          "plots_dir":"../../figures/DIST_REL_CC_04/",
          "bonds_lengths_loc":"/home/jleguy/data/stats/CC/CC_bonds_lengths_total_set.h5",
          "model_loc":"../../models/DIST_REL_CC_04/dist_rel_cc_04.tflearn"
        },
        "params":{
          "model_name":"DIST_REL_CC_03",
          "model_type":"NN",
          "anum_1":"6",
          "anum_2":"6",
          "plot_error_distrib":"True",
          "plot_targets_error_distrib":"True",
          "plot_targets_predictions":"True",
          "batch_size":"2000",
          "last_layer_width":"870",
          "depth":"3",
          "hidden_act":"elu",
          "outlayer_act":"linear",
          "display_plots":"True"
        }
      }
    }
  ]
}

# %% [markdown]
# ### Modèle DIST_REL_CC_04
#
# #### Statistiques erreurs (pm)
#
# ```
# Plotting DIST_REL_CC_03
# Dataset size : 1106823
# Mean error : 0.47271934
# Median error : 0.37729493
# Standard deviation : 0.42876694
# Min error : 0.0
# Max error : 18.209728
# Relative error : 0.31817493%
# ```
#
# #### Distribution des erreurs
#
# ![title](../figures/DIST_REL_CC_04/DIST_REL_CC_04_distrib_rmse_val.png)
#
# #### Erreurs en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CC_04/DIST_REL_CC_04_distrib_rmse_dist.png)
#
#
# #### Prédiction en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CC_04/DIST_REL_CC_04_preds_targets.png)
#
#
#
# ### Modèle DIST_REL_CH_04
#
# #### Statistiques erreurs (pm)
#
# ```
# Plotting DIST_REL_CH_04
# Dataset size : 1158250
# Mean error : 0.1659476
# Median error : 0.12419434
# Standard deviation : 0.15636328
# Min error : 0.0
# Max error : 7.235986
# Relative error : 0.15144494%
#
# ```
#
# #### Distribution des erreurs
#
# ![title](../figures/DIST_REL_CH_04/DIST_REL_CH_04_distrib_rmse_val.png)
#
#
# #### Erreurs en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CH_04/DIST_REL_CH_04_distrib_rmse_dist.png)
#
#
# #### Prédiction en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CH_04/DIST_REL_CH_04_preds_targets.png)
#
#
# ### Modèle DIST_REL_OH_04
#
# #### Statistiques erreurs (pm)
#
# ```
# Plotting DIST_REL_OH_04
# Dataset size : 143588
# Mean error : 0.24780236
# Median error : 0.20801392
# Standard deviation : 0.21109347
# Min error : 6.1035157e-06
# Max error : 6.4609556
# Relative error : 0.253514%
# ```
#
# #### Distribution des erreurs
#
# ![title](../figures/DIST_REL_OH_04/DIST_REL_OH_04_distrib_rmse_val.png)
#
# #### Erreurs en fonction des distances cibles
#
# ![title](../figures/DIST_REL_OH_04/DIST_REL_OH_04_distrib_rmse_dist.png)
#
#
# #### Prédiction en fonction des distances cibles
#
# ![title](../figures/DIST_REL_OH_04/DIST_REL_OH_04_preds_targets.png)

# %%
import numpy as np

a = np.array([5, 6, 7])
b = np.array([2, 2, 2])

np.divide(a, b)
# Out:
# array([2.5, 3. , 3.5])

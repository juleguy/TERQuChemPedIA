# %% [markdown]
# ## 13.3 Analyse des prédictions de DIST_REL_C_03 et DIST_REL_C_04
#
# Les modèles DIST_REL_C_03/04 sont identiques au modèle DIST_REL_C_02, à la différence qu'on donne l'inverse des distances à DIST_REL_C_03 et l'inverse du carré des distances à DIST_REL_C_04.
#
# ### JSON

# %%
{
  "tasks":[
    {
      "plot_predictions":{
        "paths":{
          "test_prepared_input_loc":"../../data/DIST_REL_C_03/test_set_prepared_input.h5",
          "test_labels_loc":"../../data/DIST_REL_C_03/test_set_labels.h5",
          "plots_dir":"../../figures/DIST_REL_C_03/",
          "bonds_lengths_loc":"/home/jleguy/data/stats/CC/CC_bonds_lengths_total_set.h5",
          "model_loc":"../../models/DIST_REL_C_03/DIST_REL_C_03.tflearn"
        },
        "params":{
          "model_name":"DIST_REL_C_03",
          "model_type":"NN",
          "anum_1":"6",
          "anum_2":"6",
          "plot_error_distrib":"True",
          "plot_targets_error_distrib":"True",
          "plot_targets_predictions":"True",
          "batch_size":"2000",
          "last_layer_width":"870",
          "depth":"3",
          "hidden_act":"elu",
          "outlayer_act":"linear"
        }
      }
    },
   {
      "plot_predictions":{
        "paths":{
          "test_prepared_input_loc":"../../data/DIST_REL_C_04/test_set_prepared_input.h5",
          "test_labels_loc":"../../data/DIST_REL_C_04/test_set_labels.h5",
          "plots_dir":"../../figures/DIST_REL_C_04/",
          "bonds_lengths_loc":"/home/jleguy/data/stats/CC/CC_bonds_lengths_total_set.h5",
          "model_loc":"../../models/DIST_REL_C_04/DIST_REL_C_04.tflearn"
        },
        "params":{
          "model_name":"DIST_REL_C_04",
          "model_type":"NN",
          "anum_1":"6",
          "anum_2":"6",
          "plot_error_distrib":"True",
          "plot_targets_error_distrib":"True",
          "plot_targets_predictions":"True",
          "batch_size":"2000",
          "last_layer_width":"870",
          "depth":"3",
          "hidden_act":"elu",
          "outlayer_act":"linear"
        }
      }
    }
  ]
}

# %% [markdown]
# ### DIST_REL_C_03
#
# #### Statistiques erreurs
#
# ```
# Plotting DIST_REL_C_03
# Dataset size : 554434
# Mean error : 0.62554467
# Median error : 0.4341797
# Standard deviation : 0.64336216
# Min error : 0.0
# Max error : 15.479431
# ```
#
# #### Distribution des erreurs
#
# ![title](../figures/DIST_REL_C_03/DIST_REL_C_03_distrib_rmse_val.png)
#
# #### Erreurs en fonction des distances cibles
#
# ![title](../figures/DIST_REL_C_03/DIST_REL_C_03_distrib_rmse_dist.png)
#
#
# #### Prédiction en fonction des distances cibles
#
# ![title](../figures/DIST_REL_C_03/DIST_REL_C_03_preds_targets.png)
#
# ### DIST_REL_C_04
#
# #### Statistiques erreurs
#
# ```
# Plotting DIST_REL_C_04
# Dataset size : 554434
# Mean error : 0.47425994
# Median error : 0.30860597
# Standard deviation : 0.55209047
# Min error : 0.0
# Max error : 17.517994
# ```
#
# #### Distribution des erreurs
#
# ![title](../figures/DIST_REL_C_04/DIST_REL_C_04_distrib_rmse_val.png)
#
# #### Erreurs en fonction des distances cibles
#
# ![title](../figures/DIST_REL_C_04/DIST_REL_C_04_distrib_rmse_dist.png)
#
#
# #### Prédiction en fonction des distances cibles
#
# ![title](../figures/DIST_REL_C_04/DIST_REL_C_04_preds_targets.png)

# %% [markdown]
# ## Analyse des performances des modèles DIST_REL_CC_02, DIST_REL_CH_02 et DIST_REL_OH_02
#
# Ces modèles sont identiques aux modèles DIST_REL_XY_01, à la différence qu'on ne donne aux modèles que les inforations concernant les atomes à moins de 2Å d'au moins un atome de la liaison que l'on veut prédire.

# %% [markdown]
# ### JSON

# %%
{
  "tasks":[
    {
      "plot_predictions":{
        "paths":{
          "test_prepared_input_loc":"../../data/DIST_REL_OH_02/test_prepared_input.h5",
          "test_labels_loc":"../../data/DIST_REL_OH_02/test_labels.h5",
          "plots_dir":"../../figures/DIST_REL_OH_02/",
          "bonds_lengths_loc":"/home/jleguy/data/stats/OH/OH_bonds_lengths_total_set.h5",
          "model_loc":"../../models/DIST_REL_OH_02/dist_rel_oh_02.tflearn"
        },
        "params":{
          "model_name":"DIST_REL_OH_02",
          "model_type":"NN",
          "anum_1":"8",
          "anum_2":"1",
          "plot_error_distrib":"True",
          "plot_targets_error_distrib":"True",
          "plot_targets_predictions":"True",
          "asymb_1":"O",
          "asymb_2":"H",
          "batch_size":"2000",
          "last_layer_width":"870",
          "depth":"3",
          "hidden_act":"elu",
          "outlayer_act":"linear"
        }
      }
    },
    {
      "plot_predictions":{
        "paths":{
          "test_prepared_input_loc":"../../data/DIST_REL_CH_02/test_prepared_input.h5",
          "test_labels_loc":"../../data/DIST_REL_CH_02/test_labels.h5",
          "plots_dir":"../../figures/DIST_REL_CH_02/",
          "bonds_lengths_loc":"/home/jleguy/data/stats/CH/CH_bonds_lengths_total_set.h5",
          "model_loc":"../../models/DIST_REL_CH_02/dist_rel_ch_02.tflearn"
        },
        "params":{
          "model_name":"DIST_REL_CH_02",
          "model_type":"NN",
          "anum_1":"6",
          "anum_2":"1",
          "plot_error_distrib":"True",
          "plot_targets_error_distrib":"True",
          "plot_targets_predictions":"True",
          "asymb_1":"C",
          "asymb_2":"H",
          "batch_size":"2000",
          "last_layer_width":"870",
          "depth":"3",
          "hidden_act":"elu",
          "outlayer_act":"linear"
        }
      }
    },
    {
      "plot_predictions":{
        "paths":{
          "test_prepared_input_loc":"../../data/DIST_REL_CC_02/test_prepared_input.h5",
          "test_labels_loc":"../../data/DIST_REL_CC_02/test_labels.h5",
          "plots_dir":"../../figures/DIST_REL_OH_02/",
          "bonds_lengths_loc":"/home/jleguy/data/stats/CC/CC_bonds_lengths_total_set.h5",
          "model_loc":"../../models/DIST_REL_CC_02/dist_rel_cc_02.tflearn"
        },
        "params":{
          "model_name":"DIST_REL_CC_02",
          "model_type":"NN",
          "anum_1":"6",
          "anum_2":"6",
          "plot_error_distrib":"True",
          "plot_targets_error_distrib":"True",
          "plot_targets_predictions":"True",
          "asymb_1":"C",
          "asymb_2":"C",
          "batch_size":"2000",
          "last_layer_width":"870",
          "depth":"3",
          "hidden_act":"elu",
          "outlayer_act":"linear"
        }
      }
    }
  ]
}

# %% [markdown]
# ### Modèle DIST_REL_CC_02
#
# #### Statistiques erreurs (pm)
#
# ```
# Plotting DIST_REL_CC_02
# Dataset size : 1106823
# Mean error : 0.34164444
# Median error : 0.2666626
# Standard deviation : 0.3372837
# Min error : 0.0
# Max error : 26.216663
# ```
#
#
#
# #### Distribution des erreurs
#
# ![title](../figures/DIST_REL_CC_02/DIST_REL_CC_02_distrib_rmse_val.png)
#
# #### Erreurs en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CC_02/DIST_REL_CC_02_distrib_rmse_dist.png)
#
#
# #### Prédiction en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CC_02/DIST_REL_CC_02_preds_targets.png)
#
#
#
# ### Modèle DIST_REL_CH_02
#
# #### Statistiques erreurs (pm)
#
# ```
# Plotting DIST_REL_CH_02
# Dataset size : 1158250
# Mean error : 0.23904692
# Median error : 0.20096436
# Standard deviation : 0.18838589
# Min error : 0.0
# Max error : 6.2904787
# ```
#
# #### Distribution des erreurs
#
# ![title](../figures/DIST_REL_CH_02/DIST_REL_CH_02_distrib_rmse_val.png)
#
# #### Erreurs en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CH_02/DIST_REL_CH_02_distrib_rmse_dist.png)
#
#
# #### Prédiction en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CH_02/DIST_REL_CH_02_preds_targets.png)
#
#
# ### Modèle DIST_REL_OH_02
#
# #### Statistiques erreurs (pm)
#
# ```
# Plotting DIST_REL_OH_02
# Dataset size : 143588
# Mean error : 0.15190242
# Median error : 0.10444641
# Standard deviation : 0.16482218
# Min error : 0.0
# Max error : 4.726355
#
# ```
#
#
#
# #### Distribution des erreurs
#
# ![title](../figures/DIST_REL_OH_02/DIST_REL_OH_02_distrib_rmse_val.png)
#
# #### Erreurs en fonction des distances cibles
#
# ![title](../figures/DIST_REL_OH_02/DIST_REL_OH_02_distrib_rmse_dist.png)
#
#
# #### Prédiction en fonction des distances cibles
#
# ![title](../figures/DIST_REL_OH_02/DIST_REL_OH_02_preds_targets.png)

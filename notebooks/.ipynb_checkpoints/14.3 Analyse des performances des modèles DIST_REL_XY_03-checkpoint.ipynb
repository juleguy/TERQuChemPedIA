# %% [markdown]
# ## Analyse des performances des modèles DIST_REL_XY_03
#
# Inverse du carré des distances
#
# ### JSON

# %%
{
  "tasks":[
    {
      "plot_predictions":{
        "paths":{
          "test_prepared_input_loc":"../../data/DIST_REL_OH_03/test_prepared_input.h5",
          "test_labels_loc":"../../data/DIST_REL_OH_03/test_labels.h5",
          "plots_dir":"../../figures/DIST_REL_OH_03/",
          "bonds_lengths_loc":"/home/jleguy/data/stats/OH/OH_bonds_lengths_total_set.h5",
          "model_loc":"../../models/DIST_REL_OH_03/dist_rel_oh_03.tflearn"
        },
        "params":{
          "model_name":"DIST_REL_OH_03",
          "model_type":"NN",
          "anum_1":"8",
          "anum_2":"1",
          "plot_error_distrib":"True",
          "plot_targets_error_distrib":"True",
          "plot_targets_predictions":"True",
          "batch_size":"2000",
          "last_layer_width":"870",
          "depth":"3",
          "hidden_act":"elu",
          "outlayer_act":"linear",
          "display_plots":"True"
        }
      }
    },
    {
      "plot_predictions":{
        "paths":{
          "test_prepared_input_loc":"../../data/DIST_REL_CH_03/test_prepared_input.h5",
          "test_labels_loc":"../../data/DIST_REL_CH_03/test_labels.h5",
          "plots_dir":"../../figures/DIST_REL_CH_03/",
          "bonds_lengths_loc":"/home/jleguy/data/stats/CH/CH_bonds_lengths_total_set.h5",
          "model_loc":"../../models/DIST_REL_CH_03/dist_rel_ch_03.tflearn"
        },
        "params":{
          "model_name":"DIST_REL_CH_03",
          "model_type":"NN",
          "anum_1":"6",
          "anum_2":"1",
          "plot_error_distrib":"True",
          "plot_targets_error_distrib":"True",
          "plot_targets_predictions":"True",
          "batch_size":"2000",
          "last_layer_width":"870",
          "depth":"3",
          "hidden_act":"elu",
          "outlayer_act":"linear",
          "display_plots":"True"

        }
      }
    },
    {
      "plot_predictions":{
        "paths":{
          "test_prepared_input_loc":"../../data/DIST_REL_CC_03/test_prepared_input.h5",
          "test_labels_loc":"../../data/DIST_REL_CC_03/test_labels.h5",
          "plots_dir":"../../figures/DIST_REL_CC_03/",
          "bonds_lengths_loc":"/home/jleguy/data/stats/CC/CC_bonds_lengths_total_set.h5",
          "model_loc":"../../models/DIST_REL_CC_03/dist_rel_cc_03.tflearn"
        },
        "params":{
          "model_name":"DIST_REL_CC_03",
          "model_type":"NN",
          "anum_1":"6",
          "anum_2":"6",
          "plot_error_distrib":"True",
          "plot_targets_error_distrib":"True",
          "plot_targets_predictions":"True",
          "batch_size":"2000",
          "last_layer_width":"870",
          "depth":"3",
          "hidden_act":"elu",
          "outlayer_act":"linear",
          "display_plots":"True"
        }
      }
    }
  ]
}

# %% [markdown]
# ### Modèle DIST_REL_CC_03
#
# #### Statistiques erreurs (pm)
#
# ```
# Plotting DIST_REL_CC_03
# Dataset size : 1106823
# Mean error : 0.45081505
# Median error : 0.32895508
# Standard deviation : 0.45820102
# Min error : 0.0
# Max error : 16.630285
# Relative error : 0.3017106%
# ```
#
# #### Distribution des erreurs
#
# ![title](../figures/DIST_REL_CC_03/DIST_REL_CC_03_distrib_rmse_val.png)
#
# #### Erreurs en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CC_03/DIST_REL_CC_03_distrib_rmse_dist.png)
#
#
# #### Prédiction en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CC_03/DIST_REL_CC_03_preds_targets.png)
#
#
#
# ### Modèle DIST_REL_CH_03
#
# #### Statistiques erreurs (pm)
#
# ```
# Plotting DIST_REL_CH_03
# Dataset size : 1158250
# Mean error : 0.16339429
# Median error : 0.12056885
# Standard deviation : 0.15912794
# Min error : 0.0
# Max error : 6.1820555
# Relative error : 0.14910884%
# ```
#
# #### Distribution des erreurs
#
# ![title](../figures/DIST_REL_CH_03/DIST_REL_CH_03_distrib_rmse_val.png)
#
#
# #### Erreurs en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CH_03/DIST_REL_CH_03_distrib_rmse_dist.png)
#
#
# #### Prédiction en fonction des distances cibles
#
# ![title](../figures/DIST_REL_CH_03/DIST_REL_CH_03_preds_targets.png)
#
#
# ### Modèle DIST_REL_OH_03
#
# #### Statistiques erreurs (pm)
#
# ```
# Plotting DIST_REL_OH_03
# Dataset size : 143588
# Mean error : 0.21066315
# Median error : 0.18317261
# Standard deviation : 0.174187
# Min error : 0.0
# Max error : 7.074298
# Relative error : 0.21574518%
# ```
#
# #### Distribution des erreurs
#
# ![title](../figures/DIST_REL_OH_03/DIST_REL_OH_03_distrib_rmse_val.png)
#
# #### Erreurs en fonction des distances cibles
#
# ![title](../figures/DIST_REL_OH_03/DIST_REL_OH_03_distrib_rmse_dist.png)
#
#
# #### Prédiction en fonction des distances cibles
#
# ![title](../figures/DIST_REL_OH_03/DIST_REL_OH_03_preds_targets.png)
